# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.metrics import accuracy_score

# %%
#Graphics code from Christoffer Fink in this course to visualize the network
def plot_training_data(train_input, train_target, input_color='yellow', target_color='cyan', facecolor='black', figsize=(20,10)):
    (fig, axs) = plt.subplots(nrows=1, ncols=2, figsize=figsize)
    axs[0].set_title('training input')
    axs[0].plot(train_input, color=input_color)
    axs[0].set_facecolor(facecolor)
    axs[1].set_title('target output')
    axs[1].plot(train_target, color=target_color)
    axs[1].set_facecolor(facecolor)
    plt.show()

def plot_outputs(target, output, test_input=None, output_color='magenta', input_color='yellow', target_color='cyan', error_color='red', facecolor='black', figsize=(20,10)):
    (fig, ax) = plt.subplots(figsize=figsize)
    ax.set_facecolor(facecolor)
    ax.plot(target, color=target_color, linewidth=4)
    ax.plot(output, color=output_color, linewidth=1.5)
    error = np.abs(output - target)
    ax.plot(error, color=error_color)
    if test_input is not None:
        ax.plot(test_input, color=input_color, linestyle='dotted')
    plt.show()

def plot_weight_matrix(w, ax=None, shape=None, figsize=(20,5)):
    if shape is not None:
        w = np.resize(w, shape)
    if ax is None:
        (fig, ax) = plt.subplots(figsize=figsize)
    ax.imshow(w, cmap='gray')
    if ax is None:
        plt.show()

def plot_initial_esn(win, w, win_shape=None, figsize=(20,5)):
    (fig, axs) = plt.subplots(nrows=1, ncols=2, figsize=figsize)
    ax = axs[0]
    ax.set_title('Input weights Win')
    plot_weight_matrix(win, ax=ax, shape=win_shape)
    ax = axs[1]
    ax.set_title('RNN weights W')
    plot_weight_matrix(w, ax=ax)
    plt.show()

def plot_rnn_states(xs, shape, figsize=(20,10)):
    """Plot selected RNN states as images."""
    n = xs.shape[0]
    examples = [0, n//10, -n//10, -1]
    ncols = len(examples)
    (fig, axs) = plt.subplots(nrows=1, ncols=ncols, figsize=figsize)
    for (n,i) in enumerate(examples):
        title = f'xs[{i}]'
        x = np.resize(xs[i], shape)
        axs[n].set_title(title)
        axs[n].imshow(x, cmap='gray')
    plt.show()

def plot_all_rnn_states(xs, figsize=(20,10)):
    """
    Plot all RNN states as a single image, with one state per column.
    Takes a matrix where each row is one RNN state (one x vector).
    """
    lengths = np.sqrt(np.sum(np.square(xs), axis=1)) # length of each x vector
    extent = [-0.5, len(lengths)-0.5, np.min(lengths), np.max(lengths)]
    xs = np.transpose(xs)
    (fig, ax) = plt.subplots(figsize=figsize)
    ax.set_title('All RNN state vectors and their lengths')
    ax.imshow(xs, cmap='gray')#, extent=extent)
    ax.plot(lengths, color='orange', marker='o', markersize=1)
    plt.show()

# %% [markdown]
# 1. What does teacher forcing mean?
#     - TF means that instead of feeding the feedbackloop with earlier predictions, we feed it with our desired output during training to cancel the recurrency.
# 2. What is ridge regression? Why is it useful?
#     - Technique for analyzing multiple regression data that suffers multicollinearity.
# 3. How to achieve echo state property?
#     - p(W) < 1 should ensure ESP. p(W) = spectral radius.
# 4. What is Root-Mean-Square Error (RMSE)?
#     - Meaure of deviation.

# %%
res_size = 1000 #1000 neurons
scale = 0.2
weight_in = np.random.uniform(-1,1,(res_size,2))*scale
bias = 1
p = 0.8
weight_res = np.random.uniform(-1,1,(res_size,res_size))*scale

# %%
def tanh(x):
    return np.tanh(x).real

# %%
#Reservoir weight config
eg_val1 = np.abs(np.linalg.eigvals(weight_res))
weight_res = weight_res/(max(eg_val1))*p

eg_val2 = np.linalg.eigvals(weight_res)

print(np.real(max(eg_val2))<= p+0.01)
# Out:
# True

# %%
#create training set
tr_set = []
test_set = []

print("Input weight size", weight_in.shape)

#Create input layer
for n in range(1,3000):
    u = 0.5*np.sin(n/4)
    tr_set.append(u) 

#Create testing set
for n in range(3000,4000):
    u = 0.5*np.sin(n/4)
    test_set.append(u)
    
#Convert to numpy data structure    
tr_set = np.array(tr_set)
test_set = np.array(test_set)

#Create reservoir
# Out:
# Input weight size (1000, 2)

# %%
def train(tr_set):
    weight_out = np.random.uniform(-1,1,(1,(res_size+1+1)))*scale
    #plot_weight_matrix(weight_out, shape=[3,167])
    weight_back = np.random.uniform(-1,1,(res_size,1))*scale

    #Train network
    x = np.zeros(1000)
    y = np.zeros(1)
    reg_X = []
    reg_Y = []

    discard = 1000
    rr = Ridge()

    for i in range(1,2998):
        #Varmstart
        u = np.array([tr_set[i],bias])

        res_dot = np.dot(weight_res, x)
        in_dot = np.dot(weight_in,u)
        back_dot = np.dot(weight_back,np.array([tr_set[i-1]]).real)

        conc = np.concatenate([u, x])

        x = tanh(res_dot + in_dot + back_dot)
        y = np.array(tanh(np.dot(weight_out,conc)).real)

        y_target = np.array([tr_set[i+1]]).real
        reg_X.append(conc)
        reg_Y.append(y_target)

    rr.fit(reg_X[discard:], reg_Y[discard:])
    weight_out = rr.coef_
    plot_weight_matrix(weight_out, shape=[3,167])
    return x, y, weight_out, weight_back

# %%
def testESN(test_set, x,y, weight_out, weight_back, weight_res, weight_in):
    y_tot = []
    y_target_tot = []
    error = []
    for i in range(0,len(test_set)-1):
        #Varmstart
        u = np.array([test_set[i],bias])

        res_dot = np.dot(weight_res, x)
        in_dot = np.dot(weight_in,u)
        back_dot = np.dot(weight_back,y)

        conc = np.concatenate([u, x])

        x = tanh(res_dot + in_dot + back_dot)
        y = np.array(tanh(np.dot(weight_out,conc)).real)

        y_target = np.array([test_set[i+1]]).real
        error.append(np.abs(y-y_target))
        y_tot.append(y)
        y_target_tot.append(y_target)


    #plot_outputs(np.array(y_target_tot), np.array(y_tot), facecolor='white')
    return np.array(error), np.array(y_tot)

# %%
mean_error = []
y_mean = []
for i in range(10):
    x, y, weight_out, weight_back = train(tr_set)
    error, y_i = testESN(test_set, x, y, weight_out, weight_back, weight_res, weight_in)
    mean_error.append(error)
    y_mean.append(y_i)
    
    
y_mean = np.mean(np.array(y_mean), axis=0)
mean_error = np.mean(np.array(mean_error))

plot_outputs(y_mean.flatten(), test_set[:len(test_set)-1].flatten(), facecolor='white')
print('Mean error', mean_error)
# Out:
# Mean error 0.12892500246088096

# %% [markdown]
# Using a spectral radius of 0.8 and a scale of 0.2 gave us a mean error of 0.13. Manually altering these hyper parameters gave us a mean error of 0.05 using spectral radius of 0.7 and a scale of 0.4.

# %%
# check for intuition at http://users.fs.cvut.cz/ivo.bukovsky/PVVR/prace_studentu/Mackey_Glass_time_series_prediction_Fuzzy_Lookup.pdf

def mackey_glass(tau, length):
    betta=0.2
    gamma = 0.1 
    a=10
    delay=100 # will cut these initial steps
    
    y=np.random.rand(tau) # random intial values between 0 and 1
    # Euler's method to solve the differential equation
    for t in range(tau-1, length+delay+tau-1):
        current= y[t] + ( betta * y[t-(tau-1)]   / ( 1 + np.power(y[t-(tau-1)], a)   )  ) - gamma*y[t]   
        y=np.append(y, current)
    
    y=y-1 # get rid of mean
    y=np.tanh(y) # squeze with tanh    
    
    return y[tau+delay:length+delay+tau] # return the last length elements


length=4000 # duration of the series
tau=17 # delay in the equation

mackey_set=mackey_glass(tau, length)
#plot generated time-series
plt.plot(mackey_set)
plt.show()

# %%
m_tr_set = mackey_set[:3000]
m_test_set = mackey_set[3001:4000]

mean_error = []
y_mean = []
for i in range(10):
    x, y, weight_out, weight_back = train(m_tr_set)
    error, y_i = testESN(m_test_set, x, y, weight_out, weight_back, weight_res, weight_in)
    mean_error.append(error)
    y_mean.append(y_i)
    
    
y_mean = np.mean(np.array(y_mean), axis=0)
mean_error = np.mean(np.array(mean_error))

plot_outputs(y_mean.flatten(), m_test_set[:len(m_test_set)-1].flatten(), facecolor='white')
print('Mean error', mean_error)
# Out:
# Mean error 0.045070278459906035

# %% [markdown]
# ### Comment on above graph
# cyan(blue) is the target, magenta(pink) is our predicted output, red is the error

# %% [markdown]
# <h1>Time series classification<h1>

# %%
trainDF = pd.read_csv('SwedishLeaf/SwedishLeaf_Train.tsv', delimiter='\t')
sl_tr_set = trainDF.values
testDF = pd.read_csv('SwedishLeaf/SwedishLeaf_Test.tsv', delimiter='\t')
sl_test_set = testDF.values

testDF
# Out:
#      10   2.20028   1.82008   1.36603  0.84629499  0.88681099   1.32233  \
# 0    11  2.153690  2.028390  1.833580    1.641340    1.420470  1.242790
# 1     8  1.036160  0.889494  0.898131    1.000950    0.966536  1.007320
# 2    12  1.842690  1.711410  1.518030    1.343270    1.146020  0.935946
# 3    14  2.326379  2.348569  2.128169    1.902999    1.754299  1.565309
# 4     1  2.162179  1.987429  1.744699    1.461569    1.179819  0.938479
# ..   ..       ...       ...       ...         ...         ...       ...
# 619   1  1.928090  1.737110  1.463660    1.215210    0.948920  0.782923
# 620   9  1.927760  1.761410  1.569140    1.373810    1.158100  0.967700
# 621   2  1.287250  0.999923  0.717960    0.822148    0.594677  0.303251
# 622  15  1.933880  1.827710  1.657990    1.492410    1.332710  1.138780
# 623   7  1.718760  1.610230  1.481880    1.374610    1.245880  1.139100
#
#       1.62625   1.12144  0.55564299  ...  0.71077099   1.27895   1.28389  \
# 0    1.066650  0.940780    0.785536  ...    0.538987  0.657808  0.829616
# 1    1.093060  1.172500    1.036870  ...    0.413001  0.549945  0.685654
# 2    0.746994  0.616926    0.560006  ...    0.719784  0.764677  0.815949
# 3    1.507829  1.254970    0.972944  ...    1.304910  1.097200  1.227920
# 4    0.786245  0.582881    0.556064  ...    0.162328  0.269698  0.347498
# ..        ...       ...         ...  ...         ...       ...       ...
# 619  0.669711  0.547489    0.406900  ...    0.159104  0.387476  0.476410
# 620  0.778312  0.645292    0.459122  ...    0.229673  0.418165  0.531623
# 621  0.334923  0.682918    0.462435  ...   -0.206641  0.120356  0.487595
# 622  1.023730  0.876748    0.749694  ...    0.641430  0.758716  0.900316
# 623  1.009170  0.900925    0.790942  ...    0.720133  0.836154  0.932737
#
#      0.93904399  0.55171099  0.21947799  0.71929099   1.25527   1.77335  \
# 0      0.999360    1.145930    1.301900    1.529360  1.725800  1.922720
# 1      0.627952    0.765243    0.860108    0.757232  0.803073  0.884178
# 2      0.879137    1.037530    1.183720    1.312860  1.448120  1.625820
# 3      1.547719    1.673479    1.818389    1.999299  2.085989  2.182999
# 4      0.534401    0.780794    0.935629    1.235569  1.540419  1.789209
# ..          ...         ...         ...         ...       ...       ...
# 619    0.655162    0.669250    0.817887    1.099230  1.357920  1.638100
# 620    0.725657    0.895365    1.091130    1.311680  1.508720  1.705110
# 621    0.191567    0.105113    0.407399    0.757706  0.646935  0.931889
# 622    0.986537    1.114130    1.283370    1.359680  1.543600  1.706900
# 623    1.034840    1.151480    1.252020    1.369880  1.471090  1.594080
#
#       2.18837
# 0    2.120270
# 1    1.016080
# 2    1.822550
# 3    2.299839
# 4    2.107529
# ..        ...
# 619  1.900690
# 620  1.902380
# 621  1.274120
# 622  1.901550
# 623  1.697880
#
# [624 rows x 129 columns]

# %%
res_size = 800 #800 neurons in the reservoir
scale = 0.25
weight_in = np.random.uniform(-1,1,(res_size,2))*scale
bias = 1
p = 0.99
weight_res = np.random.uniform(-1,1,(res_size,res_size))

#Reservoir weight config
eg_val1 = np.abs(np.linalg.eigvals(weight_res))
weight_res = weight_res/(max(eg_val1))*p

eg_val2 = np.linalg.eigvals(weight_res)

print(np.real(max(eg_val2))<= p+0.01)
# Out:
# True

# %%
#new ESN with 1 input and 4 outputs
def train(tr_set):
    weight_out = np.random.uniform(-1,1,((res_size+1+1),15))
    #plot_weight_matrix(weight_out, shape=[3,167])
    weight_back = np.random.uniform(-1,1,(res_size,15))

    #Train network
    x = np.zeros(res_size)
    y = np.zeros(15)
    reg_X = []
    reg_Y = []

    discard = 0
    rr = Ridge()
    
    totalpreds = 0
    freqCorrect = 0
    largCorrect = 0
    for i in range(0,len(tr_set)):
        x = np.zeros(res_size)
        label = tr_set[i][0]
        label = np.eye(15)[:][int(label)-1]
        predictions = []
        print("\rEpoch {} out of {}".format(i,len(tr_set)-1), end="\r")


        for j in range(1,len(tr_set[i])):
            
            u = np.array([bias,tr_set[i][j]])

            res_dot = np.dot(weight_res, x)
            in_dot = np.dot(weight_in,u)
            back_dot = np.dot(weight_back, label)
            
            x = tanh(res_dot + in_dot)
            
            conc = np.concatenate([u, x])

            y = conc@weight_out
            #y = np.array(tanh(np.dot(weight_out,conc)).real)
            predictions.append(np.argmax(y))
            #print("Predicted", np.argmax(y), "actual: ", np.argmax(label))
            
            reg_X.append(conc)
            reg_Y.append(label)
        #Accuracy
        totalpreds += 1
        bin = np.bincount(predictions)
        
        #Most frequent
        if(np.argmax(bin) == np.argmax(label)):
            freqCorrect += 1
            
        #Largest value
        if(bin[len(bin)-1] == np.argmax(label)):
            largCorrect += 1
        
        #Updating weight
        #rr.fit(reg_X[discard:], reg_Y[discard:])
        
        #weight_out = rr.coef_
        l= 0.0
        x_f = np.array(reg_X)
        y_f = np.array(reg_Y)
        weight_out = np.linalg.pinv(np.transpose(x_f)@x_f + l*np.diag(np.var(x_f, axis=0)))@np.transpose(x_f)@y_f
        
    print("Training accuracy (frequencey)", freqCorrect/totalpreds)
    print("Training accuracy (largest)", largCorrect/totalpreds)
    return x, y, weight_out, weight_back

# %%
def testESN(test_set, weight_out, weight_back, weight_res, weight_in):
    y_tot = []
    y_target_tot = []
    totalpreds = 0
    freqCorrect = 0
    largCorrect = 0
    y = np.zeros(15)
    for i in range(0,len(test_set)-1):
        predictions = []
        x = np.zeros(res_size)
        label = test_set[i][0]
        label = np.eye(15)[:][int(label)-1]

        for j in range(1,len(test_set[i])):
            
            u = np.array([bias,test_set[i][j]])
            
            res_dot = np.dot(weight_res, x)
            in_dot = np.dot(weight_in,u)
            #back_dot = np.dot(weight_back,y)

            conc = np.concatenate([u, x])
            
            x = tanh(res_dot + in_dot)
            
            y = conc@weight_out
            predictions.append(np.argmax(y))
            #print("Label", np.argmax(label), "y", np.argmax(y))

        #Accuracy
        totalpreds += 1
        bin = np.bincount(predictions)
        #Most frequent
        if(np.argmax(bin) == np.argmax(label)):
            freqCorrect += 1
        #Largest value
        if(bin[len(bin)-1] == np.argmax(label)):
            largCorrect += 1
        print("\r Epoch {} out of {} with accuracy {}".format(i,len(test_set)-1,freqCorrect/totalpreds), end="\r")


        y_tot.append(y)    
        y_target_tot.append(label)
    #print("Test", weight_out[:3][:3])
    print("Testing accuracy (frequencey)", freqCorrect/totalpreds)
    print("Testing accuracy (largest)", largCorrect/totalpreds)
    return np.array(y_target_tot), np.array(y_tot)

# %%
x, y, weight_out, weight_back = train(sl_tr_set)
# Out:
# Training accuracy (frequencey) 0.625250501002004
# Training accuracy (largest) 0.04408817635270541

# %%
plot_weight_matrix(weight_out.T)

# %%
y_targets, ys = testESN(sl_test_set, weight_out, weight_back, weight_res, weight_in)
# Out:
# Label 10 y 1
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 8
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 1
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 13
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 13
# Label 13 y 1
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 7
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 13
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 0 y 1t of 623 with accuracy 0.0
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 8
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 0
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 8
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 8
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 8
# Label 0 y 14
# Label 0 y 14
# Label 0 y 8
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 0
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 8
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 4 y 1t of 623 with accuracy 0.0
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 12
# Label 4 y 11
# Label 4 y 14
# Label 4 y 8
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 10
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 8
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 10 y 1 of 623 with accuracy 0.0
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 8
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 7
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 0
# Label 10 y 10
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 12 y 1 of 623 with accuracy 0.0
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 3
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 7
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 12
# Label 12 y 11
# Label 12 y 11
# Label 12 y 6
# Label 12 y 11
# Label 12 y 11
# Label 12 y 12
# Label 12 y 11
# Label 12 y 12
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 5 y 7t of 623 with accuracy 0.0
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 12
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 5
# Label 5 y 5
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 0 y 1t of 623 with accuracy 0.0
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 2
# Label 0 y 14
# Label 0 y 14
# Label 0 y 2
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 3
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 0
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 8
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 14 y 1 of 623 with accuracy 0.0
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 2
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 10
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 0
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 0
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label
# Label 2 y 11
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 11
# Label 2 y 11
# Label 2 y 14
# Label 2 y 2
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 14
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 2
# Label 2 y 11
# Label 2 y 11
# Label 2 y 14
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 2 y 11
# Label 4 y 1ut of 623 with accuracy 0.06666666666666667
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 8
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 11
# Label 4 y 4
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 14
# Label 4 y 11
# Label 4 y 11
# Label 13 y 1t of 623 with accuracy 0.058823529411764705
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 12
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 13
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 13
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 13
# Label 13 y 11
# Label 13 y 13
# Label 13 y 11
# Label 13 y 10
# Label 13 y 13
# Label 13 y 13
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 13
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 13
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 13
# Label 13 y 11
# Label 13 y 13
# Label 13 y 13
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 12
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 14
# Label 13 y 11
# Label 13 y 11
# Label 13 y 10
# Label 13 y 11
# Label 13 y 11
# Label 13 y 11
# Label 5 y 7ut of 623 with accuracy 0.05555555555555555
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 1
# Label 5 y 1
# Label 5 y 1
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 5
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 5
# Label 5 y 14
# Label 5 y 5
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 5
# Label 5 y 5
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 14 y 7t of 623 with accuracy 0.05263157894736842
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 7
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 10
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 10 y 1t of 623 with accuracy 0.05
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 14
# Label 10 y 2
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 2
# Label 10 y 13
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 3
# Label 10 y 10
# Label 10 y 2
# Label 10 y 8
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 1t of 623 with accuracy 0.047619047619047616
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 8
# Label 10 y 14
# Label 10 y 2
# Label 10 y 10
# Label 10 y 11
# Label 10 y 8
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 0
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 10
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 2
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 12 y 1t of 623 with accuracy 0.045454545454545456
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 7
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 12
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 12
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 5 y 7ut of 623 with accuracy 0.043478260869565216
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 5
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 5
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 1
# Label 5 y 1
# Label 5 y 14
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 5
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 14
# Label 5 y 11
# Label 5 y 11
# Label 5 y 5
# Label 5 y 5
# Label 5 y 5
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 5
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 5 y 11
# Label 14 y 1t of 623 with accuracy 0.041666666666666664
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 5
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 14
# Label 14 y 11
# Label 14 y 4
# Label 14 y 11
# Label 14 y 4
# Label 14 y 11
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 0
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 1t of 623 with accuracy 0.04
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 10
# Label 14 y 2
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 8
# Label 14 y 0
# Label 14 y 0
# Label 14 y 11
# Label 14 y 14
# Label 14 y 14
# Label 14 y 14
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 0
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 0
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 14 y 11
# Label 12 y 1t of 623 with accuracy 0.07692307692307693
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 12
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 11
# Label 12 y 1t of 623 with accuracy 0.07407407407407407
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 11
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 14
# Label 12 y 11
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# Label 12 y 14
# ...
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 8
# Label 10 y 8
# Label 10 y 14
# Label 10 y 11
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 8
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 1ut of 623 with accuracy 0.07835820895522388
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 10
# Label 10 y 2
# Label 10 y 8
# Label 10 y 2
# Label 10 y 2
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 0
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 1ut of 623 with accuracy 0.07806691449814127
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 2
# Label 10 y 8
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 1ut of 623 with accuracy 0.07777777777777778
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 10
# Label 10 y 11
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 7
# Label 10 y 14
# Label 10 y 3
# Label 10 y 11
# Label 10 y 2
# Label 10 y 2
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 7
# Label 10 y 11
# Label 10 y 11
# Label 10 y 7
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 1ut of 623 with accuracy 0.07749077490774908
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 10
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 14
# Label 10 y 2
# Label 10 y 8
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 6 y 1out of 623 with accuracy 0.07720588235294118
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 6
# Label 6 y 2
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 7
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 14
# Label 6 y 10
# Label 6 y 14
# Label 6 y 2
# Label 6 y 2
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 6 y 11
# Label 10 y 1ut of 623 with accuracy 0.07692307692307693
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 10
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 2
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 14
# Label 10 y 0
# Label 10 y 11
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 10
# Label 10 y 11
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 1ut of 623 with accuracy 0.07664233576642336
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 13
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 14
# Label 10 y 2
# Label 10 y 11
# Label 10 y 10
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 10 y 11
# Label 0 y 1out of 623 with accuracy 0.07636363636363637
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 8
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 8
# Label 0 y 11
# Label 0 y 8
# Label 0 y 10
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 0
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 14
# Label 0 y 8
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 14
# Label 0 y 8
# Label 0 y 8
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 8
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 14
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 0 y 11
# Label 4 y 1out of 623 with accuracy 0.07608695652173914
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14
# Label 4 y 14

# %%
for i in range(10):
    x, y, weight_out, weight_back = train(sl_tr_set)
    y_targets, ys = testESN(sl_test_set, x, y, weight_out, weight_back, weight_res, weight_in)
    #print(accuracy_score(y_targets, ys))
    break
