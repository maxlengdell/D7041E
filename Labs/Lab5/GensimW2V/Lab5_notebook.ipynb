# %%
# import modules & set up logging
import gensim, logging, numpy as np
import help_functions as hf
import nltk
nltk.download('wordnet')

#@author: The first version of this code is the courtesy of Vadim Selyanik


logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
lemmatizer = nltk.WordNetLemmatizer() # create a lemmatizer

sentences = []
file = open("lemmatized.text", "r")

for line in file: # read the file and create list which contains all sentences found in the text
    sentences.append(line.split())
# train word2vec on the two sentences

# %%
def runSynonymModel(dimension):
    threshold = 0.00055 # parameter for Word2vec


    sum = 0.0

    model = gensim.models.Word2Vec(sentences, min_count=1, sample=threshold, sg=1,size=dimension) # create model using Word2Ve with the given parameters
    #
    print(len(model.wv.vocab)) # check the length of the vocabulary which was formed by Word2Vec
    #The rest implements passing TOEFL tests
    i = 0 #counter for TOEFL tests
    number_of_tests = 80
    text_file = open('new_toefl.txt', 'r')
    right_answers = 0 # variable for correct answers
    number_skipped_tests = 0 # some tests could be skipped if there are no corresponding words in the vocabulary extracted from the training corpus
    while i < number_of_tests:
                line = text_file.readline() #read line in the file
                words = line.split() # extract words from the line
                try:
                    words = [lemmatizer.lemmatize(lemmatizer.lemmatize(lemmatizer.lemmatize(word, 'v'), 'n'), 'a') for word in
                             words] # lemmatize words in the current test
                    vectors = []
                    if words[0] in model: # check if there embedding for the query word
                        k = 1 #counter for loop iterating over 5 words in the test
                        vectors.append(model[words[0]])
                        while k < 5:
                            if words[k] in model: # if alternative has the embedding
                                vectors.append(model[words[k]]) #assing the learned vector
                            else: 
                                vectors.append(np.random.randn(dimension)) #assing random vector
                            k += 1
                        right_answers += hf.get_answer_mod(vectors) #find the closest vector and check if it is the correct answer

                except KeyError: # if there is no representation for the query vector than skip
                    number_skipped_tests += 1
                    print("skipped test: " + str(i) + "; Line: " + str(words))
                except IndexError:
                    print(i)
                    print(line)
                    print(words)
                    break
                i += 1
    text_file.close()
    sum += 100 * float(right_answers) / float(number_of_tests) #get the percentage
    print("Threshold ferq = "+ str(threshold)+" Percentage of correct answers: " + str(sum) + "%")
    return sum

# %%
dim10 = 0
dim100 = 0
dim1000 = 0
runs = 3
for i in range(runs):
    dim10 += runSynonymModel(10)
    dim100 += runSynonymModel(100)
    dim1000 += runSynonymModel(1000)
    
print("Dimension 10 mean accuracy = ",dim10/runs)
print("Dimension 100 mean accuracy = ",dim100/runs)
print("Dimension 1000 mean accuracy = ",dim1000/runs)
# Out:
# 2021-02-23 11:36:21,927 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2021-02-23 11:36:21,928 : INFO : collecting all words and their counts
# 2021-02-23 11:36:21,929 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-02-23 11:36:21,949 : INFO : PROGRESS: at sentence #10000, processed 112555 words, keeping 6354 word types
# 2021-02-23 11:36:21,976 : INFO : PROGRESS: at sentence #20000, processed 254983 words, keeping 10821 word types
# 2021-02-23 11:36:21,998 : INFO : PROGRESS: at sentence #30000, processed 367772 words, keeping 12635 word types
# 2021-02-23 11:36:22,033 : INFO : PROGRESS: at sentence #40000, processed 566573 words, keeping 17685 word types
# 2021-02-23 11:36:22,060 : INFO : PROGRESS: at sentence #50000, processed 724294 words, keeping 20496 word types
# 2021-02-23 11:36:23,627 : INFO : PROGRESS: at sentence #610000, processed 8757627 words, keeping 63211 word types
# 2021-02-23 11:36:23,658 : INFO : PROGRESS: at sentence #620000, processed 8899486 words, keeping 63809 word types
# 2021-02-23 11:36:23,688 : INFO : PROGRESS: at sentence #630000, processed 9081782 words, keeping 64483 word types
# 2021-02-23 11:36:23,718 : INFO : PROGRESS: at sentence #640000, processed 9203773 words, keeping 64821 word types
# 2021-02-23 11:36:23,750 : INFO : PROGRESS: at sentence #650000, processed 9389002 words, keeping 65876 word types
# 2021-02-23 11:36:23,785 : INFO : PROGRESS: at sentence #660000, processed 9554591 words, keeping 66413 word types
# 2021-02-23 11:36:23,813 : INFO : PROGRESS: at sentence #670000, processed 9702648 words, keeping 67288 word types
# 2021-02-23 11:36:23,836 : INFO : PROGRESS: at sentence #680000, processed 9827973 words, keeping 67596 word types
# 2021-02-23 11:36:23,859 : INFO : PROGRESS: at sentence #690000, processed 9953739 words, keeping 67868 word types
# 2021-02-23 11:36:23,886 : INFO : PROGRESS: at sentence #700000, processed 10083832 words, keeping 68162 word types
# 2021-02-23 11:36:23,911 : INFO : PROGRESS: at sentence #710000, processed 10223733 words, keeping 68816 word types
# 2021-02-23 11:36:23,940 : INFO : PROGRESS: at sentence #720000, processed 10360488 words, keeping 69381 word types
# 2021-02-23 11:36:23,961 : INFO : PROGRESS: at sentence #730000, processed 10479153 words, keeping 69774 word types
# 2021-02-23 11:36:23,989 : INFO : PROGRESS: at sentence #740000, processed 10597851 words, keeping 70112 word types
# 2021-02-23 11:36:24,016 : INFO : PROGRESS: at sentence #750000, processed 10734438 words, keeping 70523 word types
# 2021-02-23 11:36:24,024 : INFO : collected 70583 word types from a corpus of 10766283 raw words and 752149 sentences
# 2021-02-23 11:36:24,027 : INFO : Loading a fresh vocabulary
# 2021-02-23 11:36:24,172 : INFO : effective_min_count=1 retains 70583 unique words (100% of original 70583, drops 0)
# 2021-02-23 11:36:24,174 : INFO : effective_min_count=1 leaves 10766283 word corpus (100% of original 10766283, drops 0)
# 2021-02-23 11:36:24,436 : INFO : deleting the raw counts dictionary of 70583 items
# 2021-02-23 11:36:24,440 : INFO : sample=0.00055 downsamples 87 most-common words
# 2021-02-23 11:36:24,441 : INFO : downsampling leaves estimated 7342202 word corpus (68.2% of prior 10766283)
# 2021-02-23 11:36:24,672 : INFO : estimated required memory for 70583 words and 10 dimensions: 40938140 bytes
# 2021-02-23 11:36:24,673 : INFO : resetting layer weights
# 2021-02-23 11:36:38,343 : INFO : training model with 3 workers on 70583 vocabulary and 10 features, using sg=1 hs=0 sample=0.00055 negative=5 window=5
# 2021-02-23 11:36:39,351 : INFO : EPOCH 1 - PROGRESS: at 9.43% examples, 692187 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:36:40,367 : INFO : EPOCH 1 - PROGRESS: at 19.21% examples, 668421 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:36:41,374 : INFO : EPOCH 1 - PROGRESS: at 26.33% examples, 608650 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:36:42,379 : INFO : EPOCH 1 - PROGRESS: at 32.63% examples, 571765 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:36:43,408 : INFO : EPOCH 1 - PROGRESS: at 40.20% examples, 571613 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11
: INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-23 11:37:14,259 : INFO : EPOCH - 3 : training on 10766283 raw words (7340921 effective words) took 13.1s, 558899 effective words/s
# 2021-02-23 11:37:15,279 : INFO : EPOCH 4 - PROGRESS: at 6.88% examples, 503452 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:16,280 : INFO : EPOCH 4 - PROGRESS: at 16.02% examples, 554723 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:17,283 : INFO : EPOCH 4 - PROGRESS: at 25.20% examples, 583228 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:18,295 : INFO : EPOCH 4 - PROGRESS: at 35.87% examples, 627981 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:19,306 : INFO : EPOCH 4 - PROGRESS: at 45.81% examples, 654225 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:20,310 : INFO : EPOCH 4 - PROGRESS: at 56.01% examples, 668183 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:21,313 : INFO : EPOCH 4 - PROGRESS: at 65.09% examples, 677966 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:22,313 : INFO : EPOCH 4 - PROGRESS: at 73.98% examples, 681116 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:23,317 : INFO : EPOCH 4 - PROGRESS: at 83.95% examples, 685930 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:24,329 : INFO : EPOCH 4 - PROGRESS: at 91.29% examples, 671864 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:25,253 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-23 11:37:25,255 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-23 11:37:25,260 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-23 11:37:25,261 : INFO : EPOCH - 4 : training on 10766283 raw words (7343911 effective words) took 11.0s, 667822 effective words/s
# 2021-02-23 11:37:26,272 : INFO : EPOCH 5 - PROGRESS: at 8.89% examples, 648922 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:27,273 : INFO : EPOCH 5 - PROGRESS: at 18.94% examples, 665337 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:28,275 : INFO : EPOCH 5 - PROGRESS: at 28.20% examples, 659682 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:29,288 : INFO : EPOCH 5 - PROGRESS: at 36.45% examples, 639529 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:30,297 : INFO : EPOCH 5 - PROGRESS: at 44.51% examples, 639531 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:31,310 : INFO : EPOCH 5 - PROGRESS: at 53.67% examples, 641321 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:32,320 : INFO : EPOCH 5 - PROGRESS: at 61.72% examples, 640822 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:33,322 : INFO : EPOCH 5 - PROGRESS: at 69.79% examples, 634588 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:34,324 : INFO : EPOCH 5 - PROGRESS: at 74.87% examples, 612103 words/s, in_qsize 6, out_qsize 0
# 2021-02-23 11:37:35,327 : INFO : EPOCH 5 - PROGRESS: at 82.76% examples, 607216 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:36,330 : INFO : EPOCH 5 - PROGRESS: at 89.05% examples, 598342 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:37,352 : INFO : EPOCH 5 - PROGRESS: at 99.22% examples, 603290 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11:37:37,414 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-23 11:37:37,422 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-23 11:37:37,426 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-23 11:37:37,426 : INFO : EPOCH - 5 : training on 10766283 raw words (7342339 effective words) took 12.2s, 603899 effective words/s
# 2021-02-23 11:37:37,427 : INFO : training on a 53831415 raw words (36711050 effective words) took 59.1s, 621348 effective words/s
# <ipython-input-8-9de2f6b0a9f6>:23: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if words[0] in model: # check if there embedding for the query word
# <ipython-input-8-9de2f6b0a9f6>:25: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   vectors.append(model[words[0]])
# <ipython-input-8-9de2f6b0a9f6>:27: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if words[k] in model: # if alternative has the embedding
# <ipython-input-8-9de2f6b0a9f6>:28: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   vectors.append(model[words[k]]) #assing the learned vector
# 2021-02-23 11:37:37,473 : INFO : collecting all words and their counts
# 2021-02-23 11:37:37,474 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 
# 2021-02-23 11:37:38,946 : INFO : PROGRESS: at sentence #570000, processed 8220916 words, keeping 61572 word types
# 2021-02-23 11:37:38,970 : INFO : PROGRESS: at sentence #580000, processed 8337894 words, keeping 61863 word types
# 2021-02-23 11:37:38,996 : INFO : PROGRESS: at sentence #590000, processed 8467527 words, keeping 62192 word types
# 2021-02-23 11:37:39,022 : INFO : PROGRESS: at sentence #600000, processed 8601730 words, keeping 62628 word types
# 2021-02-23 11:37:39,048 : INFO : PROGRESS: at sentence #610000, processed 8757627 words, keeping 63211 word types
# 2021-02-23 11:37:39,071 : INFO : PROGRESS: at sentence #620000, processed 8899486 words, keeping 63809 word types
# 2021-02-23 11:37:39,100 : INFO : PROGRESS: at sentence #630000, processed 9081782 words, keeping 64483 word types
# 2021-02-23 11:37:39,121 : INFO : PROGRESS: at sentence #640000, processed 9203773 words, keeping 64821 word types
# 2021-02-23 11:37:39,152 : INFO : PROGRESS: at sentence #650000, processed 9389002 words, keeping 65876 word types
# 2021-02-23 11:37:39,180 : INFO : PROGRESS: at sentence #660000, processed 9554591 words, keeping 66413 word types
# 2021-02-23 11:37:39,204 : INFO : PROGRESS: at sentence #670000, processed 9702648 words, keeping 67288 word types
# 2021-02-23 11:37:39,224 : INFO : PROGRESS: at sentence #680000, processed 9827973 words, keeping 67596 word types
# 2021-02-23 11:37:39,243 : INFO : PROGRESS: at sentence #690000, processed 9953739 words, keeping 67868 word types
# 2021-02-23 11:37:39,264 : INFO : PROGRESS: at sentence #700000, processed 10083832 words, keeping 68162 word types
# 2021-02-23 11:37:39,287 : INFO : PROGRESS: at sentence #710000, processed 10223733 words, keeping 68816 word types
# 2021-02-23 11:37:39,308 : INFO : PROGRESS: at sentence #720000, processed 10360488 words, keeping 69381 word types
# 2021-02-23 11:37:39,328 : INFO : PROGRESS: at sentence #730000, processed 10479153 words, keeping 69774 word types
# 2021-02-23 11:37:39,348 : INFO : PROGRESS: at sentence #740000, processed 10597851 words, keeping 70112 word types
# 2021-02-23 11:37:39,369 : INFO : PROGRESS: at sentence #750000, processed 10734438 words, keeping 70523 word types
# 2021-02-23 11:37:39,375 : INFO : collected 70583 word types from a corpus of 10766283 raw words and 752149 sentences
# 2021-02-23 11:37:39,375 : INFO : Loading a fresh vocabulary
# 2021-02-23 11:37:40,303 : INFO : effective_min_count=1 retains 70583 unique words (100% of original 70583, drops 0)
# 2021-02-23 11:37:40,304 : INFO : effective_min_count=1 leaves 10766283 word corpus (100% of original 10766283, drops 0)
# 2021-02-23 11:37:40,508 : INFO : deleting the raw counts dictionary of 70583 items
# 2021-02-23 11:37:40,511 : INFO : sample=0.00055 downsamples 87 most-common words
# 2021-02-23 11:37:40,512 : INFO : downsampling leaves estimated 7342202 word corpus (68.2% of prior 10766283)
# 2021-02-23 11:37:40,737 : INFO : estimated required memory for 70583 words and 100 dimensions: 91757900 bytes
# 2021-02-23 11:37:40,738 : INFO : resetting layer weights
# 2021-02-23 11:37:53,366 : INFO : training model with 3 workers on 70583 vocabulary and 100 features, using sg=1 hs=0 sample=0.00055 negative=5 window=5
# 2021-02-23 11:37:54,378 : INFO : EPOCH 1 - PROGRESS: at 6.78% examples, 500364 words/s, in_qsize 5, out_qsize 0
# 2021-02-23 11
import numpy as np
import text_functions as tf
import nltk

#@author: The first version of this code is the courtesy of Vadim Selyanik

threshold = 15000 # Frequency threshold in the corpus ??
dimension = 2000 # Dimensionality for high-dimensional vectors
lemmatizer = nltk.WordNetLemmatizer()  # create an instance of lemmatizer
ones_number = 2 # number of nonzero elements in randomly generated high-dimensional vectors
window_size = 2 #number of neighboring words to consider both back and forth. In other words number of words before/after current word
zero_vector = np.zeros(dimension)
test_name = "new_toefl.txt" # file with TOEFL dataset
data_file_name = "lemmatized.text" # file with the text corpus

amount_dictionary = {}

# Count how many times each word appears in the corpus
text_file = open(data_file_name, "r")
for line in text_file:
    if line != "\n":
        words = line.split()
        for word in words:
            if amount_dictionary.get(word) is None:
                amount_dictionary[word] = 1
            else:
                amount_dictionary[word] += 1
text_file.close()

dictionary = {} #vocabulary and corresponing random high-dimensional vectors
word_space = {} #embedings




#Create a dictionary with the assigned random high-dimensional vectors
text_file = open(data_file_name, "r")
for line in text_file: #read line in the file
    words = line.split() # extract words from the line
    for word in words:  # for each word
        if dictionary.get(word) is None: # If the word was not yed added to the vocabulary
            if amount_dictionary[word] < threshold:
                dictionary[word] = tf.get_random_word_vector(dimension, ones_number) # assign a  
            else:
                dictionary[word] = np.zeros(dimension) # frequent words are assigned with empty vectors. In a way they will not contribute to the word embedding

text_file.close()
#Note that in order to save time we only create embeddings for the words needed in the TOEFL task

#Find all unique words amongst TOEFL tasks and initialize their embeddings to zeros    
number_of_tests = 0
text_file = open(test_name, "r") #open TOEFL tasks
for line in text_file:
        words = line.split()
        words = [lemmatizer.lemmatize(lemmatizer.lemmatize(lemmatizer.lemmatize(word, 'v'), 'n'), 'a') for word in
                 words] # lemmatize words in the current test
        word_space[words[0]] = np.zeros(dimension)
        word_space[words[1]] = np.zeros(dimension)
        word_space[words[2]] = np.zeros(dimension)
        word_space[words[3]] = np.zeros(dimension)
        word_space[words[4]] = np.zeros(dimension)
        number_of_tests += 1
text_file.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-3a7a891b4789> in <module>
#       1 import numpy as np
# ----> 2 import text_functions as tf
#       3 import nltk
#       4
#       5 #@author: The first version of this code is the courtesy of Vadim Selyanik
#
# ModuleNotFoundError: No module named 'text_functions'

# %%
# Processing the text to build the embeddings 
text_file = open(data_file_name, "r")
lines = [[],[],[],[]] # neighboring lines
i = 2
while i < 4:
        line = "\n"
        while line == "\n":
            line = text_file.readline()
        lines[i] = line.split()
        i += 1

line = text_file.readline()
while line != "":
        if line != "\n":
            lines.append(line.split())
            words = lines[2]
            length = len(words)
            i = 0
            while i < length:
                if not (word_space.get(words[i]) is None):
                    k = 1
                    word_space_vector = word_space[words[i]]
                    while (i - k >= 0) and (k <= window_size): #process left neighbors of the focus word
                        word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[words[i - k]], -1))         
                        k += 1
                    # Handle different situations if there was not enough neighbors on the left in the current line    
                    if k <= window_size and (len(lines[1])>0): 
                        if len(lines[1]) < 2:
                            if k != 1: #if one word on the left was already added
                                word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[lines[1][0]], -1)) #update word embedding
                            else:
                                word_space[words[i]] = np.add(word_space[words[i]],
                                                              np.roll(dictionary[lines[1][0]], -1)) #update word embedding
                                word_space[words[i]] = np.add(word_space[words[i]],
                                                              np.roll(dictionary[lines[0][len(lines[0]) - 1]], -1)) #update word embedding
                        else:
                            if k != 1:
                                word_space[words[i]] = np.add(word_space[words[i]],
                                                              np.roll(dictionary[lines[1][len(lines[1]) - 1]], -1)) #update word embedding
                            else:
                                word_space[words[i]] = np.add(word_space[words[i]],
                                                              np.roll(dictionary[lines[1][len(lines[1]) - 1]], -1)) #update word embedding
                                word_space[words[i]] = np.add(word_space[words[i]],
                                                              np.roll(dictionary[lines[1][len(lines[1]) - 2]], -1)) #update word embedding

                    k = 1
                    while (i + k < length) and (k <= window_size): #process right neighbors of the focus word
                        word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[words[i + k]], 1)) #update word embedding
                        k += 1
                    if k <= window_size:
                        if len(lines[3]) < 2:
                            if k != 1:
                                word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[lines[3][0]], 1)) #update word embedding
                            else:
                                word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[lines[3][0]], 1)) #update word embedding
                                word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[lines[4][0]], 1)) #update word embedding
                        else:
                            if k != 1:
                                word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[lines[3][0]], 1)) #update word embedding
                            else:
                                word_space[words[i]] = np.add(word_space[words[i]], np.roll(dictionary[lines[3][0]], 1)) #update word embedding
                                word_space[words[i]] = np.add(word_space[words[i]],
                                                          np.roll(dictionary[lines[3][1]], 1))

                i += 1
            lines.pop(0)
        line = text_file.readline()



#Testing of the embeddings on TOEFL
a = 0.0 # accuracy of the encodings    
i = 0
text_file = open(test_name, 'r')
right_answers = 0.0 # variable for correct answers
number_skipped_tests = 0.0 # some tests could be skipped if there are no corresponding words in the vocabulary extracted from the training corpus
while i < number_of_tests:
        line = text_file.readline() #read line in the file
        words = line.split()  # extract words from the line
        words = [lemmatizer.lemmatize(lemmatizer.lemmatize(lemmatizer.lemmatize(word, 'v'), 'n'), 'a') for word in
                  words]  # lemmatize words in the current test
        try:
            
            if not(amount_dictionary.get(words[0]) is None): # check if there word in the corpus for the query word
                k = 1
                while k < 5:
                    # if amount_dictionary.get(words[k]) is None:
                    #     word_space[words[k]] = np.random.randn(dimension)
                    if np.array_equal(word_space[words[k]], zero_vector): # if no representation was learnt assign a random vector
                        word_space[words[k]] = np.random.randn(dimension)
                    k += 1
                right_answers += tf.get_answer_mod([word_space[words[0]],word_space[words[1]],word_space[words[2]],
                            word_space[words[3]],word_space[words[4]]]) #check if word is predicted right
        except KeyError: # if there is no representation for the query vector than skip
            number_skipped_tests += 1
            print("skipped test: " + str(i) + "; Line: " + str(words))
        except IndexError:
            print(i)
            print(line)
            print(words)
            break
        i += 1
text_file.close()
a += 100 * right_answers / number_of_tests
print(str(dimension) + " Percentage of correct answers: " + str(100 * right_answers / number_of_tests) + "%")
